# %% [markdown]
# # Automated Feature Engineering
# #### See https://www.kaggle.com/willkoehrsen/automated-feature-engineering-tutorial

# %%
# Required libraries
import pandas as pd
import numpy as np
import featuretools as ft
import warnings
warnings.filterwarnings('ignore')

# %%
# So we have the entities and 2 types of transaction
# clients -< loans -< payments

clients = pd.read_csv('../input/clients.csv',parse_dates=['joined'])
loans = pd.read_csv('../input/loans.csv',parse_dates=['loan_start','loan_end'])
payments = pd.read_csv('../input/payments.csv',parse_dates=['payment_date'])

# %%
# Rollup payments to loan_id then merge into loans
stats = payments.groupby('loan_id')['payment_amount','missed'].agg(['sum'])
stats.columns = ['payment','missed']

loans2 = loans.merge(stats, left_on='loan_id', right_index=True, how='left')
loans2.head()
# Out:
#    client_id loan_type  loan_amount  repaid  loan_id loan_start   loan_end  \
# 0      46109      home        13672       0    10243 2002-04-16 2003-12-20
# 1      46109    credit         9794       0    10984 2003-10-21 2005-07-17
# 2      46109      home        12734       1    10990 2006-02-01 2007-07-05
# 3      46109      cash        12518       1    10596 2010-12-08 2013-05-05
# 4      46109    credit        14049       1    11415 2010-07-07 2012-05-21
#
#    rate  payment  missed
# 0  2.15    14008       4
# 1  1.25     7791       3
# 2  0.68    12178       2
# 3  1.24     7681       4
# 4  3.13    16052       4

# %%
# Now rollup to client id and merge into clients

stats = loans2.groupby('client_id')['loan_amount','payment','missed'].agg(['sum'])
stats.columns = ['loan_amount','payment','missed']
clients2 = clients.merge(stats, left_on='client_id', right_index=True, how='left')

# Then add some features manually
clients2['join_month'] = clients2['joined'].dt.month
clients2['log_income'] = np.log(clients2['income'])
clients2.head()
# 5 new features with 7 lines of code
# Out:
#    client_id     joined  income  credit_score  loan_amount  payment  missed  \
# 0      46109 2002-04-16  172677           527       179032   193954      68
# 1      49545 2007-11-14  104564           770       205786   282907     111
# 2      41480 2013-03-11  122607           585       157897   188223      68
# 3      46180 2001-11-06   43851           562       154017   176796      62
# 4      25707 2006-10-06  211422           621       159279   189747      85
#
#    join_month  log_income
# 0           4   12.059178
# 1          11   11.557555
# 2           3   11.716739
# 3          11   10.688553
# 4          10   12.261611

# %% [markdown]
# ## OK Let's use featuretools

# %%
# An ft entity is simply a data-frame. And ft uses sets of them - an entityset!
# Basically we're creating metadata. NB payments has no payment_id, so create one.
es = ft.EntitySet(id = 'myentityset')
es = es.entity_from_dataframe(entity_id = 'clients', 
                              dataframe=clients, 
                              index='client_id',
                              time_index='joined')

es = es.entity_from_dataframe(entity_id = 'loans', 
                              dataframe=loans, 
                              variable_types = {'repaid': ft.variable_types.Categorical},
                              index='loan_id',
                              time_index='loan_start')

es = es.entity_from_dataframe(entity_id = 'payments', 
                              dataframe=payments, 
                              variable_types = {'missed': ft.variable_types.Categorical},
                              make_index = True,
                              index='payment_id',
                              time_index='payment_date')

# %%
# Right, lets have a look. Its just metadata in a dict
es['loans']
# Out:
# Entity: loans
#   Variables:
#     loan_id (dtype: index)
#     client_id (dtype: numeric)
#     loan_type (dtype: categorical)
#     loan_amount (dtype: numeric)
#     loan_start (dtype: datetime_time_index)
#     loan_end (dtype: datetime)
#     rate (dtype: numeric)
#     repaid (dtype: categorical)
#   Shape:
#     (Rows: 443, Columns: 8)

# %%
# Now we have to tell ft how these entities are related
# Uses the parent-child metaphor. Create the relationships then add to  the entity set
r_c_l = ft.Relationship(es['clients']['client_id'],
                        es['loans']['client_id'])
r_l_p = ft.Relationship(es['loans']['loan_id'],
                        es['payments']['loan_id'])
es = es.add_relationship(r_c_l)
es = es.add_relationship(r_l_p)

# %%
# Another look at the whole lot
es
# Out:
# Entityset: myentityset
#   Entities:
#     clients [Rows: 25, Columns: 4]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     loans.client_id -> clients.client_id
#     payments.loan_id -> loans.loan_id

# %%
# Ok Now lets make some features. First some primitives
# Either aggregations or transformations
primitives = ft.list_primitives()
pd.options.display.max_colwidth=100
primitives[primitives['type']=='aggregation'].head(20)
# Out:
#                 name         type  \
# 0             median  aggregation
# 1    time_since_last  aggregation
# 2   avg_time_between  aggregation
# 3           num_true  aggregation
# 4                all  aggregation
# 5               mode  aggregation
# 6      n_most_common  aggregation
# 7         num_unique  aggregation
# 8                any  aggregation
# 9               mean  aggregation
# 10               min  aggregation
# 11               max  aggregation
# 12      percent_true  aggregation
# 13              last  aggregation
# 14               sum  aggregation
# 15               std  aggregation
# 16             count  aggregation
# 17              skew  aggregation
# 18             trend  aggregation
#
#                                                                 description
# 0           Finds the median value of any feature with well-ordered values.
# 1                                         Time since last related instance.
# 2                     Computes the average time between consecutive events.
# 3                           Finds the number of 'True' values in a boolean.
# 4                                            Test if all values are 'True'.
# 5                   Finds the most common element in a categorical feature.
# 6                Finds the N most common elements in a categorical feature.
# 7                       Returns the number of unique categorical variables.
# 8                                              Test if any value is 'True'.
# 9                          Computes the average value of a numeric feature.
# 10                   Finds the minimum non-null value of a numeric feature.
# 11                   Finds the maximum non-null value of a numeric feature.
# 12                 Finds the percent of 'True' values in a boolean feature.
# 13                                                  Returns the last value.
# 14                           Sums elements of a numeric or boolean feature.
# 15  Finds the standard deviation of a numeric feature ignoring null values.
# 16                                    Counts the number of non null values.
# 17                                     Computes the skewness of a data set.
# 18           Calculates the slope of the linear trend of variable overtime.

# %%
# And
primitives[primitives['type']=='transform'].head(20)
# Out:
#                    name       type  \
# 19                 isin  transform
# 20  time_since_previous  transform
# 21                years  transform
# 22                  mod  transform
# 23               months  transform
# 24             multiply  transform
# 25                weeks  transform
# 26                  and  transform
# 27                  add  transform
# 28               second  transform
# 29              minutes  transform
# 30              seconds  transform
# 31              cum_min  transform
# 32            longitude  transform
# 33                 hour  transform
# 34           time_since  transform
# 35            cum_count  transform
# 36           percentile  transform
# 37                  day  transform
# 38           characters  transform
#
#                                                                                            description
# 19                        For each value of the base feature, checks whether it is in a provided list.
# 20                                                       Compute the time since the previous instance.
# 21                                             Transform a Timedelta feature into the number of years.
# 22                                              Creates a transform feature that divides two features.
# 23                                            Transform a Timedelta feature into the number of months.
# 24                                            Creates a transform feature that multplies two features.
# 25                                             Transform a Timedelta feature into the number of weeks.
# 26                                        For two boolean values, determine if both values are 'True'.
# 27                                                 Creates a transform feature that adds two features.
# 28                                                       Transform a Datetime feature into the second.
# 29                                           Transform a Timedelta feature into the number of minutes.
# 30                                           Transform a Timedelta feature into the number of seconds.
# 31     Calculates the min of previous values of an instance for each value in a time-dependent entity.
# 32                                                 Returns the second value on the tuple base feature.
# 33                                                         Transform a Datetime feature into the hour.
# 34                                                              Calculates time since the cutoff time.
# 35  Calculates the number of previous values of an instance for each value in a time-dependent entity.
# 36                           For each value of the base feature, determines the percentile in relation
# 37                                                          Transform a Datetime feature into the day.
# 38                                                            Return the characters in a given string.

# %%
# Ok lets do it! Make some features for the clients
features, feature_names = ft.dfs(entityset = es,
                                 target_entity='clients',
                                 agg_primitives=['median','mean','std','max','percent_true','last','time_since_last'],
                                 trans_primitives=['years','month','divide'])

# %%
# Wow! 408  features in 4 lines of code (140 new ones)
# I'm already sold on this!
len(feature_names)
# Out:
# 408

# %%
feature_names
# Out:
# [<Feature: income>,
#  <Feature: credit_score>,
#  <Feature: MEDIAN(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate)>,
#  <Feature: STD(loans.loan_amount)>,
#  <Feature: STD(loans.rate)>,
#  <Feature: MAX(loans.loan_amount)>,
#  <Feature: MAX(loans.rate)>,
#  <Feature: LAST(loans.loan_type)>,
#  <Feature: LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.rate)>,
#  <Feature: LAST(loans.repaid)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.missed)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MONTH(joined)>,
#  <Feature: income / credit_score>,
#  <Feature: credit_score / income>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.loan_amount / rate)>,
#  <Feature: MEDIAN(loans.rate / loan_amount)>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.loan_amount / rate)>,
#  <Feature: MEAN(loans.rate / loan_amount)>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount))>,
#  <Feature: STD(loans.LAST(payments.payment_amount))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.loan_amount / rate)>,
#  <Feature: STD(loans.rate / loan_amount)>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.STD(payments.payment_amount))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.loan_amount / rate)>,
#  <Feature: MAX(loans.rate / loan_amount)>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.STD(payments.payment_amount))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.MONTH(loan_start))>,
#  <Feature: LAST(loans.MONTH(loan_end))>,
#  <Feature: LAST(loans.loan_amount / rate)>,
#  <Feature: LAST(loans.rate / loan_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.LAST(payments.payment_date))>,
#  <Feature: MONTH(LAST(loans.loan_start))>,
#  <Feature: MONTH(LAST(loans.loan_end))>,
#  <Feature: MONTH(LAST(payments.payment_date))>,
#  <Feature: STD(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: income / STD(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / credit_score>,
#  <Feature: STD(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / credit_score>,
#  <Feature: MEDIAN(loans.rate) / LAST(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: credit_score / MEDIAN(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MAX(loans.rate)>,
#  <Feature: LAST(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: MAX(loans.rate) / MEDIAN(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / STD(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / credit_score>,
#  <Feature: LAST(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: STD(payments.payment_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEDIAN(loans.rate)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: MAX(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / MAX(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: STD(loans.rate) / income>,
#  <Feature: LAST(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / credit_score>,
#  <Feature: LAST(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / credit_score>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: credit_score / MAX(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: LAST(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: income / STD(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: credit_score / LAST(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MAX(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: income / LAST(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEDIAN(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / STD(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEDIAN(loans.rate)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: LAST(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / STD(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.rate) / credit_score>,
#  <Feature: MAX(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / income>,
#  <Feature: income / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / income>,
#  <Feature: LAST(loans.rate) / MEAN(loans.rate)>,
#  <Feature: income / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / credit_score>,
#  <Feature: MAX(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / income>,
#  <Feature: MEAN(loans.rate) / STD(loans.rate)>,
#  <Feature: STD(loans.rate) / LAST(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: LAST(loans.rate) / credit_score>,
#  <Feature: LAST(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MAX(loans.loan_amount) / income>,
#  <Feature: LAST(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / income>,
#  <Feature: MAX(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEAN(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: MEDIAN(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / credit_score>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / LAST(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / income>,
#  <Feature: MAX(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: credit_score / MEAN(loans.rate)>,
#  <Feature: credit_score / MEDIAN(loans.rate)>,
#  <Feature: STD(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: credit_score / MAX(payments.payment_amount)>,
#  <Feature: credit_score / MEDIAN(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / STD(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / income>,
#  <Feature: MEDIAN(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / MEAN(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MAX(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / LAST(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEDIAN(loans.loan_amount)>,
#  <Feature: income / MEAN(loans.rate)>,
#  <Feature: STD(loans.rate) / MAX(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: credit_score / STD(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / income>,
#  <Feature: STD(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: MEAN(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / STD(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: income / MAX(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: income / STD(loans.loan_amount)>,
#  <Feature: credit_score / MAX(loans.rate)>,
#  <Feature: MEAN(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / income>,
#  <Feature: MEAN(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / income>,
#  <Feature: MEAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEAN(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(payments.payment_amount) / income>,
#  <Feature: LAST(loans.loan_amount) / STD(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEAN(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: LAST(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / STD(loans.loan_amount)>,
#  <Feature: income / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MAX(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEAN(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / STD(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / credit_score>,
#  <Feature: MEDIAN(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / credit_score>,
#  <Feature: MEDIAN(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / LAST(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MAX(loans.rate)>,
#  <Feature: LAST(loans.rate) / MEDIAN(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / STD(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MAX(loans.loan_amount)>,
#  <Feature: credit_score / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: STD(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / credit_score>,
#  <Feature: LAST(loans.loan_amount) / income>,
#  <Feature: MAX(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / credit_score>,
#  <Feature: MEDIAN(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: income / MEAN(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / credit_score>,
#  <Feature: LAST(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: MEAN(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: LAST(loans.rate) / STD(loans.rate)>,
#  <Feature: STD(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: income / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: MEAN(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: STD(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: MEDIAN(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MAX(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / credit_score>,
#  <Feature: income / LAST(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / credit_score>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: income / MEDIAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / income>,
#  <Feature: MEAN(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MAX(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: credit_score / MEAN(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MAX(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / income>,
#  <Feature: LAST(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / STD(loans.rate)>,
#  <Feature: MEDIAN(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / STD(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: STD(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: STD(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: credit_score / LAST(loans.loan_amount)>,
#  <Feature: STD(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: income / MAX(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: income / MEDIAN(loans.rate)>,
#  <Feature: credit_score / STD(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: credit_score / LAST(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: STD(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MAX(loans.rate)>,
#  <Feature: credit_score / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(loans.loan_amount) / income>,
#  <Feature: MAX(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / income>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / LAST(loans.rate)>,
#  <Feature: MEAN(loans.rate) / LAST(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: STD(loans.rate) / MEDIAN(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: STD(loans.rate) / MEAN(loans.rate)>,
#  <Feature: credit_score / MEAN(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: credit_score / STD(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / STD(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: income / LAST(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / MAX(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: MEAN(loans.rate) / MEDIAN(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: income / MAX(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: MEAN(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / LAST(loans.rate)>,
#  <Feature: MAX(loans.rate) / credit_score>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEAN(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / STD(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / STD(payments.payment_amount)>]

# %%
# Some interesting column names!
# Here is a feature of depth=1 ie only 1 layer of primitives has been used
pd.DataFrame(features['MEAN(payments.payment_amount)'].head())
# Out:
#            MEAN(payments.payment_amount)
# client_id
# 25707                        1178.552795
# 26326                        1166.736842
# 26695                        1207.433824
# 26945                        1109.473214
# 29841                        1439.433333

# %%
# A feature of depth=2
pd.DataFrame(features['LAST(loans.MEAN(payments.payment_amount))'].head())
# Out:
#            LAST(loans.MEAN(payments.payment_amount))
# client_id
# 25707                                     293.500000
# 26326                                     977.375000
# 26695                                    1769.166667
# 26945                                    1598.666667
# 29841                                    1125.500000

# %%
# Number of features  increases to 3530 with depth=3
features, feature_names = ft.dfs(entityset = es,
                                 target_entity='clients',
                                 agg_primitives=['median','mean','std','max','percent_true','last','time_since_last'],
                                 trans_primitives=['years','month','divide'],
                                 max_depth=3)

# %%
len(feature_names)
# Out:
# 3530

# %%
feature_names
# Out:
# [<Feature: income>,
#  <Feature: credit_score>,
#  <Feature: MEDIAN(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate)>,
#  <Feature: STD(loans.loan_amount)>,
#  <Feature: STD(loans.rate)>,
#  <Feature: MAX(loans.loan_amount)>,
#  <Feature: MAX(loans.rate)>,
#  <Feature: LAST(loans.loan_type)>,
#  <Feature: LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.rate)>,
#  <Feature: LAST(loans.repaid)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.missed)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MONTH(joined)>,
#  <Feature: income / credit_score>,
#  <Feature: credit_score / income>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.loan_amount / rate)>,
#  <Feature: MEDIAN(loans.rate / loan_amount)>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.loan_amount / rate)>,
#  <Feature: MEAN(loans.rate / loan_amount)>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount))>,
#  <Feature: STD(loans.LAST(payments.payment_amount))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.loan_amount / rate)>,
#  <Feature: STD(loans.rate / loan_amount)>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.STD(payments.payment_amount))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.loan_amount / rate)>,
#  <Feature: MAX(loans.rate / loan_amount)>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.STD(payments.payment_amount))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.MONTH(loan_start))>,
#  <Feature: LAST(loans.MONTH(loan_end))>,
#  <Feature: LAST(loans.loan_amount / rate)>,
#  <Feature: LAST(loans.rate / loan_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.LAST(payments.payment_date))>,
#  <Feature: LAST(payments.MONTH(payment_date))>,
#  <Feature: MONTH(LAST(loans.loan_start))>,
#  <Feature: MONTH(LAST(loans.loan_end))>,
#  <Feature: MONTH(LAST(payments.payment_date))>,
#  <Feature: STD(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(loans.rate) / LAST(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / income>,
#  <Feature: LAST(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: credit_score / MAX(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEDIAN(loans.rate)>,
#  <Feature: MAX(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / LAST(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / LAST(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: STD(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: credit_score / MAX(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / STD(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / MEAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MAX(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / LAST(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / income>,
#  <Feature: MAX(loans.rate) / STD(loans.rate)>,
#  <Feature: MEAN(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / STD(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: MEAN(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / credit_score>,
#  <Feature: MEDIAN(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: MEAN(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEAN(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MAX(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / credit_score>,
#  <Feature: MEAN(payments.payment_amount) / credit_score>,
#  <Feature: income / MEDIAN(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / STD(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / STD(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: STD(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: credit_score / LAST(loans.loan_amount)>,
#  <Feature: income / MAX(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MAX(loans.rate)>,
#  <Feature: credit_score / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MAX(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: STD(loans.rate) / MEAN(loans.rate)>,
#  <Feature: credit_score / MEAN(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: income / MAX(loans.rate)>,
#  <Feature: MAX(loans.rate) / credit_score>,
#  <Feature: LAST(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: LAST(payments.payment_amount) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: income / STD(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / MAX(loans.rate)>,
#  <Feature: LAST(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / STD(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / credit_score>,
#  <Feature: income / STD(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: income / LAST(loans.rate)>,
#  <Feature: LAST(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: LAST(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MAX(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / income>,
#  <Feature: income / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / income>,
#  <Feature: MAX(loans.loan_amount) / income>,
#  <Feature: MAX(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: credit_score / MEDIAN(loans.rate)>,
#  <Feature: LAST(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / income>,
#  <Feature: MAX(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / MAX(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: credit_score / MAX(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / income>,
#  <Feature: MEAN(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / income>,
#  <Feature: MEDIAN(payments.payment_amount) / income>,
#  <Feature: STD(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: MEAN(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / credit_score>,
#  <Feature: MEDIAN(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / credit_score>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / LAST(loans.loan_amount)>,
#  <Feature: credit_score / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEAN(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: STD(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: STD(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: STD(loans.rate) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: income / MEDIAN(loans.rate)>,
#  <Feature: MEAN(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / STD(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / LAST(loans.rate)>,
#  <Feature: STD(loans.rate) / MEDIAN(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / STD(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MEDIAN(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / credit_score>,
#  <Feature: MEDIAN(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEDIAN(loans.rate)>,
#  <Feature: MAX(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: LAST(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / credit_score>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: LAST(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: credit_score / LAST(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MAX(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEAN(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / credit_score>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEAN(loans.loan_amount)>,
#  <Feature: income / MEAN(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / MEAN(loans.rate)>,
#  <Feature: LAST(payments.payment_amount) / credit_score>,
#  <Feature: MEAN(loans.rate) / STD(loans.rate)>,
#  <Feature: LAST(loans.rate) / credit_score>,
#  <Feature: MEAN(loans.loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / income>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEAN(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / income>,
#  <Feature: MAX(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: STD(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MAX(loans.rate)>,
#  <Feature: MEAN(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: income / MAX(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / STD(loans.rate)>,
#  <Feature: income / STD(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: LAST(loans.loan_amount) / STD(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEAN(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / STD(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: MAX(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MAX(loans.rate)>,
#  <Feature: LAST(loans.rate) / MEDIAN(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / STD(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / credit_score>,
#  <Feature: MAX(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / credit_score>,
#  <Feature: MEDIAN(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: income / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: credit_score / MEAN(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: STD(loans.loan_amount) / income>,
#  <Feature: MAX(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / LAST(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / LAST(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: credit_score / STD(payments.payment_amount)>,
#  <Feature: credit_score / LAST(payments.payment_amount)>,
#  <Feature: STD(loans.rate) / STD(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / income>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / income>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / LAST(loans.rate)>,
#  <Feature: credit_score / STD(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: income / LAST(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / MAX(loans.rate)>,
#  <Feature: LAST(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(payments.payment_amount) / MAX(loans.rate)>,
#  <Feature: MAX(loans.rate) / LAST(loans.rate)>,
#  <Feature: STD(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / STD(payments.payment_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / credit_score>,
#  <Feature: MEDIAN(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: credit_score / MEDIAN(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / MEDIAN(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / credit_score>,
#  <Feature: STD(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: LAST(loans.rate) / MAX(loans.rate)>,
#  <Feature: MEDIAN(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: STD(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEDIAN(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / STD(loans.rate)>,
#  <Feature: STD(loans.loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / MEAN(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / STD(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MAX(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / income>,
#  <Feature: MEAN(loans.loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: MAX(payments.payment_amount) / STD(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / MEDIAN(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / LAST(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / credit_score>,
#  <Feature: credit_score / MEAN(loans.rate)>,
#  <Feature: STD(loans.rate) / MAX(payments.payment_amount)>,
#  <Feature: credit_score / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / LAST(payments.payment_amount)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEAN(loans.rate)>,
#  <Feature: income / MEAN(loans.rate)>,
#  <Feature: MEDIAN(payments.payment_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: credit_score / STD(loans.loan_amount)>,
#  <Feature: STD(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MEDIAN(payments.payment_amount)>,
#  <Feature: MAX(payments.payment_amount) / MEDIAN(loans.rate)>,
#  <Feature: MEAN(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / LAST(loans.rate)>,
#  <Feature: income / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(loans.rate) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MAX(loans.loan_amount)>,
#  <Feature: MAX(loans.loan_amount) / MEDIAN(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / income>,
#  <Feature: income / MEAN(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / STD(loans.rate)>,
#  <Feature: MAX(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / MEAN(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / LAST(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / LAST(payments.payment_amount)>,
#  <Feature: income / LAST(loans.loan_amount)>,
#  <Feature: MAX(loans.rate) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / income>,
#  <Feature: MEAN(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(loans.loan_amount) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MAX(loans.loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: LAST(loans.rate) / LAST(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / STD(payments.payment_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEAN(payments.payment_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.rate)>,
#  <Feature: STD(loans.rate) / MEAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / STD(loans.rate)>,
#  <Feature: LAST(loans.rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: LAST(payments.payment_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: STD(loans.rate) / STD(payments.payment_amount)>,
#  <Feature: MEAN(loans.rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEAN(loans.rate)>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEDIAN(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date) / MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.loan_amount / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount) / rate)>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount) / loan_amount)>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date) / LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date) / rate)>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.rate / MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.rate / MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.rate / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.loan_amount / STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount) / loan_amount)>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date) / STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount) / rate)>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount) / loan_amount)>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount) / rate)>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.loan_amount / MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount) / rate)>,
#  <Feature: MEDIAN(loans.loan_amount / MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.rate / LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.rate / STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.loan_amount / LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date) / loan_amount)>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount) / loan_amount)>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount) / loan_amount)>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount) / rate)>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.rate / MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.loan_amount / MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date) / MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date) / MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.loan_amount / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount) / rate)>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount) / loan_amount)>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date) / LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date) / rate)>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate / MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate / MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.rate / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.loan_amount / STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount) / loan_amount)>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date) / STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount) / rate)>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount) / loan_amount)>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount) / rate)>,
#  <Feature: MEAN(loans.STD(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.loan_amount / MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount) / rate)>,
#  <Feature: MEAN(loans.loan_amount / MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate / LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate / STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.loan_amount / LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date) / loan_amount)>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEAN(payments.payment_amount) / loan_amount)>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount) / loan_amount)>,
#  <Feature: MEAN(loans.STD(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount) / rate)>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate / MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.loan_amount / MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date) / MAX(payments.payment_amount))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date) / MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.LAST(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount) / rate)>,
#  <Feature: STD(loans.MEAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: STD(loans.STD(payments.payment_amount) / loan_amount)>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date) / LAST(payments.payment_amount))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date) / rate)>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: STD(loans.STD(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.rate / MAX(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: STD(loans.rate / MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.rate / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.LAST(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / STD(payments.payment_amount))>,
#  <Feature: STD(loans.LAST(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount) / loan_amount)>,
#  <Feature: STD(loans.LAST(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date) / STD(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount) / rate)>,
#  <Feature: STD(loans.MAX(payments.payment_amount) / loan_amount)>,
#  <Feature: STD(loans.MEAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.STD(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.LAST(payments.payment_amount) / rate)>,
#  <Feature: STD(loans.STD(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount) / rate)>,
#  <Feature: STD(loans.loan_amount / MAX(payments.payment_amount))>,
#  <Feature: STD(loans.rate / LAST(payments.payment_amount))>,
#  <Feature: STD(loans.STD(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: STD(loans.rate / STD(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / LAST(payments.payment_amount))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date) / loan_amount)>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount) / loan_amount)>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.LAST(payments.payment_amount) / loan_amount)>,
#  <Feature: STD(loans.STD(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date) / MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.STD(payments.payment_amount) / rate)>,
#  <Feature: STD(loans.MAX(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.LAST(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: STD(loans.rate / MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date) / MAX(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date) / MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MAX(loans.loan_amount / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount) / rate)>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.STD(payments.payment_amount) / loan_amount)>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date) / LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date) / rate)>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MAX(loans.MAX(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.STD(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.rate / MAX(payments.payment_amount))>,
#  <Feature: MAX(loans.MAX(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.rate / MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.rate / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.loan_amount / STD(payments.payment_amount))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount) / loan_amount)>,
#  <Feature: MAX(loans.LAST(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date) / STD(payments.payment_amount))>,
#  <Feature: MAX(loans.MAX(payments.payment_amount) / rate)>,
#  <Feature: MAX(loans.MAX(payments.payment_amount) / loan_amount)>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MAX(loans.MAX(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.STD(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount) / rate)>,
#  <Feature: MAX(loans.STD(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.loan_amount / MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.MAX(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount) / rate)>,
#  <Feature: MAX(loans.loan_amount / MAX(payments.payment_amount))>,
#  <Feature: MAX(loans.rate / LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.STD(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MAX(loans.rate / STD(payments.payment_amount))>,
#  <Feature: MAX(loans.loan_amount / LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date) / loan_amount)>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount) / loan_amount)>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount) / loan_amount)>,
#  <Feature: MAX(loans.STD(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date) / MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.STD(payments.payment_amount) / rate)>,
#  <Feature: MAX(loans.MAX(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: MAX(loans.rate / MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.loan_amount / MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date) / MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.MONTH(LAST(payments.payment_date)))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date) / MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.LAST(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.loan_amount / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount) / rate)>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: LAST(loans.STD(payments.payment_amount) / loan_amount)>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date) / LAST(payments.payment_amount))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date) / rate)>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: LAST(loans.STD(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.rate / MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: LAST(loans.rate / MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.rate / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.LAST(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.loan_amount / STD(payments.payment_amount))>,
#  <Feature: LAST(loans.LAST(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount) / loan_amount)>,
#  <Feature: LAST(loans.LAST(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date) / STD(payments.payment_amount))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount) / rate)>,
#  <Feature: LAST(loans.MAX(payments.payment_amount) / loan_amount)>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.STD(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.LAST(payments.payment_amount) / rate)>,
#  <Feature: LAST(loans.STD(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.loan_amount / MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount) / rate)>,
#  <Feature: LAST(loans.loan_amount / MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.rate / LAST(payments.payment_amount))>,
#  <Feature: LAST(loans.STD(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.rate / STD(payments.payment_amount))>,
#  <Feature: LAST(loans.loan_amount / LAST(payments.payment_amount))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount) / TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date) / loan_amount)>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount) / MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount) / loan_amount)>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount) / MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.LAST(payments.payment_amount) / loan_amount)>,
#  <Feature: LAST(loans.STD(payments.payment_amount) / LAST(payments.payment_amount))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date) / MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.STD(payments.payment_amount) / rate)>,
#  <Feature: LAST(loans.MAX(payments.payment_amount) / MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.LAST(payments.payment_amount) / STD(payments.payment_amount))>,
#  <Feature: LAST(loans.rate / MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.loan_amount / MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date) / MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.loan_amount / rate) / LAST(payments.payment_amount)>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / MEDIAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount)) / STD(payments.payment_amount)>,
#  <Feature: STD(loans.MAX(payments.payment_amount)) / MAX(loans.rate)>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount)) / MEDIAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.rate / loan_amount) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(loans.rate / loan_amount) / MAX(payments.payment_amount)>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date)) / credit_score>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount)) / credit_score>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount)) / TIME_SINCE_LAST(loans.LAST(payments.payment_date))>,
#  <Feature: STD(loans.loan_amount / rate) / MEAN(loans.rate / loan_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MAX(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.loan_amount / rate)>,
#  <Feature: MEAN(loans.STD(payments.payment_amount)) / MAX(loans.LAST(payments.payment_amount))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount)) / MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: LAST(payments.payment_amount) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.STD(payments.payment_amount)) / MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(payments.payment_amount) / STD(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount)) / MAX(loans.loan_amount)>,
#  <Feature: STD(loans.loan_amount) / MEAN(loans.rate / loan_amount)>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date)) / MEAN(payments.payment_amount)>,
#  <Feature: MAX(loans.LAST(payments.payment_amount)) / MEDIAN(payments.payment_amount)>,
# ...
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(payments.payment_amount)>,
#  <Feature: MEDIAN(loans.loan_amount) / MEAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.loan_amount) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount) / LAST(loans.STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount)) / MEAN(payments.payment_amount)>,
#  <Feature: STD(payments.payment_amount) / STD(loans.LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / MEAN(loans.LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount)) / MEAN(loans.rate / loan_amount)>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date)) / MEAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount)) / MEAN(loans.loan_amount / rate)>,
#  <Feature: MEAN(loans.rate) / STD(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.rate / loan_amount) / MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.loan_amount) / STD(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.loan_amount / rate) / STD(loans.rate / loan_amount)>,
#  <Feature: LAST(payments.payment_amount) / MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate / loan_amount) / LAST(loans.MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.rate) / STD(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount)) / MEAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.loan_amount) / STD(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MAX(payments.payment_amount)) / MEDIAN(loans.loan_amount)>,
#  <Feature: LAST(loans.loan_amount / rate) / STD(loans.loan_amount / rate)>,
#  <Feature: STD(loans.loan_amount / rate) / LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(payments.payment_amount) / MEAN(loans.loan_amount / rate)>,
#  <Feature: STD(loans.rate / loan_amount) / LAST(loans.MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.rate / loan_amount) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.STD(payments.payment_amount))>,
#  <Feature: LAST(loans.rate) / MAX(loans.rate / loan_amount)>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount)) / STD(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate / loan_amount) / STD(loans.MAX(payments.payment_amount))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount)) / LAST(loans.loan_amount)>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.loan_amount / rate) / MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date)) / STD(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.rate) / TIME_SINCE_LAST(loans.LAST(payments.payment_date))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount)) / MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount)) / TIME_SINCE_LAST(loans.LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount)) / STD(loans.MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount)) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date)) / STD(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.rate / loan_amount) / STD(loans.LAST(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date)) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount)) / MEAN(loans.loan_amount)>,
#  <Feature: MAX(loans.STD(payments.payment_amount)) / MEAN(loans.rate)>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(payments.payment_amount) / MEDIAN(loans.LAST(payments.payment_amount))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount)) / MAX(loans.loan_amount / rate)>,
#  <Feature: MAX(loans.rate) / MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount)) / LAST(loans.rate)>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount)) / STD(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount)) / MEDIAN(loans.loan_amount / rate)>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount)) / LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount)) / LAST(loans.MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(payments.payment_amount) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: income / LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / rate) / LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(loans.MAX(payments.payment_amount))>,
#  <Feature: LAST(loans.loan_amount) / LAST(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount)) / MEAN(loans.STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount)) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date)) / MAX(loans.rate / loan_amount)>,
#  <Feature: MEAN(loans.loan_amount / rate) / MEAN(loans.rate / loan_amount)>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount)) / MEDIAN(loans.rate)>,
#  <Feature: MAX(loans.rate / loan_amount) / LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount)) / MEDIAN(loans.rate)>,
#  <Feature: STD(loans.LAST(payments.payment_amount)) / MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.rate / loan_amount) / STD(loans.rate)>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date)) / MEDIAN(loans.STD(payments.payment_amount))>,
#  <Feature: MAX(loans.STD(payments.payment_amount)) / MEDIAN(loans.STD(payments.payment_amount))>,
#  <Feature: MEAN(loans.MEDIAN(payments.payment_amount)) / MEDIAN(loans.LAST(payments.payment_amount))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount)) / MEAN(payments.payment_amount)>,
#  <Feature: STD(loans.rate / loan_amount) / credit_score>,
#  <Feature: MAX(loans.loan_amount / rate) / TIME_SINCE_LAST(loans.loan_start)>,
#  <Feature: MAX(loans.rate / loan_amount) / MEAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.rate) / MEDIAN(loans.LAST(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / rate) / TIME_SINCE_LAST(loans.LAST(payments.payment_date))>,
#  <Feature: MAX(loans.STD(payments.payment_amount)) / credit_score>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount)) / MEDIAN(loans.rate)>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount)) / MEAN(loans.rate)>,
#  <Feature: income / MAX(loans.rate / loan_amount)>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount)) / MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount)) / LAST(payments.payment_amount)>,
#  <Feature: MAX(loans.rate / loan_amount) / LAST(loans.MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date)) / MEDIAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.rate) / MEAN(loans.LAST(payments.payment_amount))>,
#  <Feature: STD(loans.rate / loan_amount) / LAST(loans.loan_amount / rate)>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount)) / MAX(loans.loan_amount)>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / TIME_SINCE_LAST(loans.LAST(payments.payment_date))>,
#  <Feature: income / LAST(loans.MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount)) / LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount)) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.rate) / MEAN(loans.STD(payments.payment_amount))>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(payments.payment_amount) / MEDIAN(loans.loan_amount / rate)>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date)) / MAX(loans.loan_amount)>,
#  <Feature: MEAN(loans.rate / loan_amount) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / rate) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount / rate) / LAST(loans.rate / loan_amount)>,
#  <Feature: MAX(loans.LAST(payments.payment_amount)) / STD(loans.rate / loan_amount)>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.rate / loan_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.LAST(payments.payment_date)) / STD(loans.rate)>,
#  <Feature: MEDIAN(loans.rate / loan_amount) / MEDIAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate) / MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.MEAN(payments.payment_amount)) / MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.loan_amount) / MEAN(loans.STD(payments.payment_amount))>,
#  <Feature: MEAN(payments.payment_amount) / MEDIAN(loans.rate / loan_amount)>,
#  <Feature: TIME_SINCE_LAST(loans.LAST(payments.payment_date)) / MEAN(loans.rate)>,
#  <Feature: STD(payments.payment_amount) / MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount)) / MEDIAN(loans.STD(payments.payment_amount))>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount)) / STD(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.STD(payments.payment_amount)) / MEAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate / loan_amount) / LAST(loans.loan_amount)>,
#  <Feature: MAX(payments.payment_amount) / LAST(loans.MEAN(payments.payment_amount))>,
#  <Feature: MAX(payments.payment_amount) / STD(loans.MAX(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount / rate) / credit_score>,
#  <Feature: TIME_SINCE_LAST(loans.LAST(payments.payment_date)) / MEDIAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount)) / MAX(loans.LAST(payments.payment_amount))>,
#  <Feature: TIME_SINCE_LAST(payments.payment_date) / MEDIAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.MEDIAN(payments.payment_amount)) / MAX(loans.rate)>,
#  <Feature: MAX(loans.loan_amount) / MEDIAN(loans.loan_amount / rate)>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount)) / MEAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: STD(loans.MAX(payments.payment_amount)) / LAST(loans.loan_amount)>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount)) / MAX(loans.rate / loan_amount)>,
#  <Feature: MEAN(payments.payment_amount) / MEDIAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.STD(payments.payment_amount))>,
#  <Feature: MEDIAN(payments.payment_amount) / LAST(loans.loan_amount / rate)>,
#  <Feature: LAST(loans.MEAN(payments.payment_amount)) / STD(loans.loan_amount)>,
#  <Feature: STD(loans.MEAN(payments.payment_amount)) / MEAN(loans.LAST(payments.payment_amount))>,
#  <Feature: STD(loans.rate / loan_amount) / MEAN(loans.rate / loan_amount)>,
#  <Feature: MEAN(loans.rate / loan_amount) / MEAN(loans.loan_amount / rate)>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / MEAN(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: LAST(loans.rate) / STD(loans.rate / loan_amount)>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.STD(payments.payment_amount))>,
#  <Feature: LAST(loans.rate / loan_amount) / STD(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount)) / TIME_SINCE_LAST(payments.payment_date)>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount)) / MEDIAN(loans.rate)>,
#  <Feature: LAST(loans.MEDIAN(payments.payment_amount)) / LAST(loans.rate)>,
#  <Feature: MAX(loans.MEAN(payments.payment_amount)) / MAX(loans.loan_amount)>,
#  <Feature: LAST(loans.rate / loan_amount) / MAX(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: STD(loans.loan_amount / rate) / LAST(loans.STD(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MAX(payments.payment_amount)) / MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: MAX(loans.rate) / MEAN(loans.LAST(payments.payment_amount))>,
#  <Feature: STD(loans.MAX(payments.payment_amount)) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount)) / MAX(loans.MEAN(payments.payment_amount))>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date)) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: STD(loans.MEDIAN(payments.payment_amount)) / LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(payments.payment_amount) / LAST(loans.loan_amount / rate)>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / MEAN(loans.rate)>,
#  <Feature: MAX(loans.MEDIAN(payments.payment_amount)) / LAST(loans.loan_amount / rate)>,
#  <Feature: MEDIAN(loans.LAST(payments.payment_amount)) / STD(loans.LAST(payments.payment_amount))>,
#  <Feature: MAX(loans.LAST(payments.payment_amount)) / MEDIAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.MAX(payments.payment_amount)) / MEAN(loans.loan_amount / rate)>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MAX(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.loan_amount)>,
#  <Feature: MEAN(loans.LAST(payments.payment_amount)) / LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: TIME_SINCE_LAST(loans.LAST(payments.payment_date)) / STD(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.TIME_SINCE_LAST(payments.payment_date)) / MEAN(loans.loan_amount)>,
#  <Feature: LAST(loans.rate) / LAST(loans.loan_amount / rate)>,
#  <Feature: MAX(loans.LAST(payments.payment_amount)) / LAST(loans.rate)>,
#  <Feature: MAX(loans.loan_amount / rate) / MEDIAN(loans.MAX(payments.payment_amount))>,
#  <Feature: TIME_SINCE_LAST(loans.loan_start) / MAX(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.rate / loan_amount) / MEDIAN(loans.rate)>,
#  <Feature: MAX(loans.LAST(payments.payment_amount)) / MEDIAN(loans.loan_amount / rate)>,
#  <Feature: MAX(loans.rate / loan_amount) / LAST(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount)) / STD(payments.payment_amount)>,
#  <Feature: MEAN(loans.loan_amount) / MEAN(loans.MEAN(payments.payment_amount))>,
#  <Feature: MEAN(loans.rate / loan_amount) / LAST(loans.loan_amount / rate)>,
#  <Feature: STD(loans.MEAN(payments.payment_amount)) / LAST(loans.rate / loan_amount)>,
#  <Feature: LAST(loans.STD(payments.payment_amount)) / MAX(loans.TIME_SINCE_LAST(payments.payment_date))>,
#  <Feature: MEAN(loans.STD(payments.payment_amount)) / TIME_SINCE_LAST(loans.LAST(payments.payment_date))>,
#  <Feature: MEDIAN(loans.STD(payments.payment_amount)) / MEAN(loans.loan_amount)>,
#  <Feature: MEDIAN(loans.rate / loan_amount) / MEAN(loans.MEDIAN(payments.payment_amount))>,
#  <Feature: MEDIAN(loans.MEAN(payments.payment_amount)) / LAST(loans.rate)>,
#  <Feature: LAST(loans.STD(payments.payment_amount)) / LAST(loans.rate)>,
#  <Feature: LAST(loans.STD(payments.payment_amount)) / LAST(loans.loan_amount / rate)>,
#  <Feature: MEDIAN(loans.loan_amount / rate) / MEDIAN(loans.loan_amount)>,
#  <Feature: STD(loans.TIME_SINCE_LAST(payments.payment_date)) / MAX(loans.rate / loan_amount)>,
#  <Feature: LAST(loans.TIME_SINCE_LAST(payments.payment_date)) / LAST(loans.rate)>,
#  ...]
